# %% [markdown]
# способы, как отрисовать простой график зависимости зарплаты от даты

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = read_txt(r"C:\Users\DEMO\Downloads\income.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-bf62d2ca93aa> in <module>
# ----> 1 data = read_txt(r"C:\Users\DEMO\Downloads\income.csv")
#
# NameError: name 'read_txt' is not defined

# %%
data.plot()

# %%
data.income.plot()

# %%
data.plot(kind='line')

# %%
data['income'].plot()

# %%
sns.lineplot(x=data.index,y=data.income)

# %%
plt.plot(data.index,data.income)

# %%
sns.lineplot(data=data)

# %% [markdown]
# #### Задача Main role in dota

# %%
row_dota_data = pd.read_csv(r"C:\Users\DEMO\Downloads\dota_hero_stats.csv")
row_dota_data
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota_data = pd.read_csv(r"C:\Users\DEMO\Downloads\dota_hero_stats.csv"\
                        , converters={'roles': lambda x: x[1:-1].count(',')})

# %%
dota_data.groupby(['roles']).agg({'localized_name':'count'})
dota_data.localized_name.nunique()
dota_data
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  roles
# 0          npc_dota_hero_antimage          agi      2
# 1               npc_dota_hero_axe          str      3
# 2              npc_dota_hero_bane          int      3
# 3       npc_dota_hero_bloodseeker          agi      4
# ...

# %%
dota_data.groupby(['localized_name']).agg({'roles':'max'})\
.sort_values(['roles'], ascending=False)
# Out:
#                   roles
# localized_name
# Kunkka                5
# Meepo                 5
# Naga Siren            5
# Tiny                  5
# Pangolier             5
# ...                 ...
# Pugna                 1
# Templar Assassin      1
# Techies               1
# Shadow Fiend          1
# Zeus                  0
#
# [117 rows x 1 columns]

# %%
dota_data.groupby(['localized_name']).agg({'roles':'max'}).describe()
# Out:
#             roles
# count  117.000000
# mean     3.000000
# std      1.090713
# min      0.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000

# %%
dota_data.roles.hist()

# %%
dota_data.hist()
